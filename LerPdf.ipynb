# %%
import pandas as Data

Excel = Data.read_excel(r'Grafico.xlsx')

stop_temas = Excel.columns.tolist()

stop_temas = stop_temas[1:]

print(stop_temas)

stop_tema = input('Escolha um tema abaixo')
stop_letra = input("Escolha uma letra: ").upper()
if stop_letra == "A":
    stop_numero = 0
if stop_letra == "B":
    stop_numero = 1
if stop_letra == "C":
    stop_numero = 2
if stop_letra == "D":
    stop_numero = 3
if stop_letra == "E":
    stop_numero = 4
if stop_letra == "F":
    stop_numero = 5
if stop_letra == "G":
    stop_numero = 6
if stop_letra == "H":
    stop_numero = 7
if stop_letra == "I":
    stop_numero = 8
if stop_letra == "J":
    stop_numero = 9
if stop_letra == "K":
    stop_numero = 10
if stop_letra == "L":
    stop_numero = 11
if stop_letra == "M":
    stop_numero = 12
if stop_letra == "N":
    stop_numero = 13
if stop_letra == "O":
    stop_numero = 14
if stop_letra == "P":
    stop_numero = 15
if stop_letra == "Q":
    stop_numero = 16
if stop_letra == "R":
    stop_numero = 17
if stop_letra == "S":
    stop_numero = 18
if stop_letra == "T":
    stop_numero = 19
if stop_letra == "U":
    stop_numero = 20
if stop_letra == "V":
    stop_numero = 21
if stop_letra == "W":
    stop_numero = 22
if stop_letra == "X":
    stop_numero = 23
if stop_letra == "Y":
    stop_numero = 24
if stop_letra == "Z":
    stop_numero = 25
# display(Excel[[stop_tema]])

stop_letra = Excel[Excel['Stop!'] == stop_letra]

# display(stop_letra)
stop_celula = Excel.loc[stop_numero, stop_tema]
print(f"Você Escolheu: {stop_celula}")
# Out:
# ['Animais', 'Nomes', 'Bebidas', 'Cor', 'Filme', 'País']
# Você Escolheu: Salmao
